# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('SCMS_Delivery_History_Dataset.csv')

# %%
data.head()
# Out:
#    ID Project Code            PQ # PO / SO # ASN/DN #        Country  \
# 0   1   100-CI-T01  Pre-PQ Process    SCMS-4    ASN-8  Côte d'Ivoire
# 1   3   108-VN-T01  Pre-PQ Process   SCMS-13   ASN-85        Vietnam
# 2   4   100-CI-T01  Pre-PQ Process   SCMS-20   ASN-14  Côte d'Ivoire
# 3  15   108-VN-T01  Pre-PQ Process   SCMS-78   ASN-50        Vietnam
# 4  16   108-VN-T01  Pre-PQ Process   SCMS-81   ASN-55        Vietnam
#
#   Managed By  Fulfill Via Vendor INCO Term Shipment Mode  ...  \
# 0   PMO - US  Direct Drop              EXW           Air  ...
# 1   PMO - US  Direct Drop              EXW           Air  ...
# 2   PMO - US  Direct Drop              FCA           Air  ...
# 3   PMO - US  Direct Drop              EXW           Air  ...
# 4   PMO - US  Direct Drop              EXW           Air  ...
#
#   Unit of Measure (Per Pack) Line Item Quantity Line Item Value Pack Price  \
# 0                         30                 19           551.0      29.00
# ...

# %%
data.describe().T
# Out:
#                               count           mean            std  min  \
# ID                          10324.0   51098.968229   31944.332496  1.0
# Unit of Measure (Per Pack)  10324.0      77.990895      76.579764  1.0
# Line Item Quantity          10324.0   18332.534870   40035.302961  1.0
# Line Item Value             10324.0  157650.567347  345292.066979  0.0
# Pack Price                  10324.0      21.910241      45.609223  0.0
# Unit Price                  10324.0       0.611701       3.275808  0.0
# Line Item Insurance (USD)   10037.0     240.117626     500.190568  0.0
#
#                                    25%        50%          75%         max
# ID                          12795.7500  57540.500   83648.2500    86823.00
# Unit of Measure (Per Pack)     30.0000     60.000      90.0000     1000.00
# Line Item Quantity            408.0000   3000.000   17039.7500   619999.00
# Line Item Value              4314.5925  30471.465  166447.1400  5951990.40
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10324 entries, 0 to 10323
# Data columns (total 33 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID                            10324 non-null  int64
#  1   Project Code                  10324 non-null  object
#  2   PQ #                          10324 non-null  object
#  3   PO / SO #                     10324 non-null  object
#  4   ASN/DN #                      10324 non-null  object
#  5   Country                       10324 non-null  object
#  6   Managed By                    10324 non-null  object
#  7   Fulfill Via                   10324 non-null  object
#  8   Vendor INCO Term              10324 non-null  object
#  9   Shipment Mode                 9964 non-null   object
#  10  PQ First Sent to Client Date  10324 non-null  object
#  11  PO Sent to Vendor Date        10324 non-null  object
# ...

# %%
# duplicate values check
data.duplicated().sum()
# Out:
# 0

# %%
# replce space with _ 
data.columns = data.columns.str.replace(" ","_")

# %%
data
# Out:
#           ID Project_Code            PQ_# PO_/_SO_# ASN/DN_#        Country  \
# 0          1   100-CI-T01  Pre-PQ Process    SCMS-4    ASN-8  Côte d'Ivoire
# 1          3   108-VN-T01  Pre-PQ Process   SCMS-13   ASN-85        Vietnam
# 2          4   100-CI-T01  Pre-PQ Process   SCMS-20   ASN-14  Côte d'Ivoire
# 3         15   108-VN-T01  Pre-PQ Process   SCMS-78   ASN-50        Vietnam
# 4         16   108-VN-T01  Pre-PQ Process   SCMS-81   ASN-55        Vietnam
# ...      ...          ...             ...       ...      ...            ...
# 10319  86818   103-ZW-T30       FPQ-15197  SO-50020  DN-4307       Zimbabwe
# 10320  86819   104-CI-T30       FPQ-15259  SO-50102  DN-4313  Côte d'Ivoire
# 10321  86821   110-ZM-T30       FPQ-14784  SO-49600  DN-4316         Zambia
# 10322  86822   200-ZW-T30       FPQ-16523  SO-51680  DN-4334       Zimbabwe
# 10323  86823   103-ZW-T30       FPQ-15197  SO-50022  DN-4336       Zimbabwe
#
# ...

# %%
for columns in data.select_dtypes(include=["object"]):
    print(columns)
# Out:
# Project_Code
# PQ_#
# PO_/_SO_#
# ASN/DN_#
# Country
# Managed_By
# Fulfill_Via
# Vendor_INCO_Term
# Shipment_Mode
# PQ_First_Sent_to_Client_Date
# PO_Sent_to_Vendor_Date
# Scheduled_Delivery_Date
# Delivered_to_Client_Date
# Delivery_Recorded_Date
# Product_Group
# Sub_Classification
# Vendor
# Item_Description
# Molecule/Test_Type
# Brand
# Dosage
# Dosage_Form
# Manufacturing_Site
# First_Line_Designation
# Weight_(Kilograms)
# Freight_Cost_(USD)

# %%
for columns in data.select_dtypes(include=["int" ,"float"]):
    print(columns)
# Out:
# ID
# Unit_of_Measure_(Per_Pack)
# Line_Item_Quantity
# Line_Item_Value
# Pack_Price
# Unit_Price
# Line_Item_Insurance_(USD)

# %%
# int dtype columns
int_columns = [x for x in data.select_dtypes(include=["int"])]

# %%
# float dtype columns 

float_columns  = [x for x in data.select_dtypes(include=["float"])]

# %%
# object types data
object_columns = [x for x in data.select_dtypes(include=["object"])]

# %%
# time data type

# %%
for column in data.columns:
    unique_values = data[column].unique()
    value_counts = data[column].value_counts()
    
    print(f"Unique values in column '{column}': {len(unique_values)}")
    print("\n")
    print(f"Value counts in column '{column}':\n{value_counts}")
    print("**********************************************************************************")
# Out:
# Unique values in column 'ID': 10324
#
#
# Value counts in column 'ID':
# 1        1
# 82565    1
# 82594    1
# 82595    1
# 82596    1
#         ..
# 26571    1
# 26576    1
# 26590    1
# 26591    1
# 86823    1
# Name: ID, Length: 10324, dtype: int64
# **********************************************************************************
# Unique values in column 'Project_Code': 142
#
#
# Value counts in column 'Project_Code':
# 116-ZA-T30    768
# 104-CI-T30    729
# 151-NG-T30    628
# 114-UG-T30    596
# 108-VN-T30    522
#              ...
# 100-SN-T01      1
# 201-UG-T30      1
# 100-GN-T30      1
# A02-SN-T50      1
# 104-SZ-T30      1
# Name: Project_Code, Length: 142, dtype: int64
# **********************************************************************************
# Unique values in column 'PQ_#': 1237
#
#
# Value counts in column 'PQ_#':
# Pre-PQ Process    2681
# FPQ-14942          205
# FPQ-12522          154
# FPQ-13973          110
# FPQ-4537            98
# ...

# %%
# object columns less than 1200 unique values 

for column in object_columns:
    unique_values_count = len(data[column].unique())
    if unique_values_count < 1200:
        print(f"{column}: {unique_values_count}")
# Out:
# Project_Code: 142
# Country: 43
# Managed_By: 4
# Fulfill_Via: 2
# Vendor_INCO_Term: 8
# Shipment_Mode: 5
# PQ_First_Sent_to_Client_Date: 765
# PO_Sent_to_Vendor_Date: 897
# Product_Group: 5
# Sub_Classification: 6
# Vendor: 73
# Item_Description: 184
# Molecule/Test_Type: 86
# Brand: 48
# Dosage: 55
# Dosage_Form: 17
# Manufacturing_Site: 88
# First_Line_Designation: 2

# %%
object_columns_great_than_1200 = [columns for columns in object_columns if len(data[columns].unique()) > 1200]

# %%
object_columns_great_than_1200
# Out:
# ['PQ_#',
#  'PO_/_SO_#',
#  'ASN/DN_#',
#  'Scheduled_Delivery_Date',
#  'Delivered_to_Client_Date',
#  'Delivery_Recorded_Date',
#  'Weight_(Kilograms)',
#  'Freight_Cost_(USD)']

# %%
data
# Out:
#           ID Project_Code            PQ_# PO_/_SO_# ASN/DN_#        Country  \
# 0          1   100-CI-T01  Pre-PQ Process    SCMS-4    ASN-8  Côte d'Ivoire
# 1          3   108-VN-T01  Pre-PQ Process   SCMS-13   ASN-85        Vietnam
# 2          4   100-CI-T01  Pre-PQ Process   SCMS-20   ASN-14  Côte d'Ivoire
# 3         15   108-VN-T01  Pre-PQ Process   SCMS-78   ASN-50        Vietnam
# 4         16   108-VN-T01  Pre-PQ Process   SCMS-81   ASN-55        Vietnam
# ...      ...          ...             ...       ...      ...            ...
# 10319  86818   103-ZW-T30       FPQ-15197  SO-50020  DN-4307       Zimbabwe
# 10320  86819   104-CI-T30       FPQ-15259  SO-50102  DN-4313  Côte d'Ivoire
# 10321  86821   110-ZM-T30       FPQ-14784  SO-49600  DN-4316         Zambia
# 10322  86822   200-ZW-T30       FPQ-16523  SO-51680  DN-4334       Zimbabwe
# 10323  86823   103-ZW-T30       FPQ-15197  SO-50022  DN-4336       Zimbabwe
#
# ...

# %%
data.columns
# Out:
# Index(['ID', 'Project_Code', 'PQ_#', 'PO_/_SO_#', 'ASN/DN_#', 'Country',
#        'Managed_By', 'Fulfill_Via', 'Vendor_INCO_Term', 'Shipment_Mode',
#        'PQ_First_Sent_to_Client_Date', 'PO_Sent_to_Vendor_Date',
#        'Scheduled_Delivery_Date', 'Delivered_to_Client_Date',
#        'Delivery_Recorded_Date', 'Product_Group', 'Sub_Classification',
#        'Vendor', 'Item_Description', 'Molecule/Test_Type', 'Brand', 'Dosage',
#        'Dosage_Form', 'Unit_of_Measure_(Per_Pack)', 'Line_Item_Quantity',
#        'Line_Item_Value', 'Pack_Price', 'Unit_Price', 'Manufacturing_Site',
#        'First_Line_Designation', 'Weight_(Kilograms)', 'Freight_Cost_(USD)',
#        'Line_Item_Insurance_(USD)'],
#       dtype='object')

# %%
columns_to_remove = ['PQ_First_Sent_to_Client_Date' ,'PO_Sent_to_Vendor_Date' , 'ID' , 'Project_Code' , 'PQ_#', 'PO_/_SO_#', 'ASN/DN_#']




data.drop(columns_to_remove , axis=1 , inplace=True)

# %%
data
# Out:
#              Country Managed_By  Fulfill_Via Vendor_INCO_Term Shipment_Mode  \
# 0      Côte d'Ivoire   PMO - US  Direct Drop              EXW           Air
# 1            Vietnam   PMO - US  Direct Drop              EXW           Air
# 2      Côte d'Ivoire   PMO - US  Direct Drop              FCA           Air
# 3            Vietnam   PMO - US  Direct Drop              EXW           Air
# 4            Vietnam   PMO - US  Direct Drop              EXW           Air
# ...              ...        ...          ...              ...           ...
# 10319       Zimbabwe   PMO - US     From RDC   N/A - From RDC         Truck
# 10320  Côte d'Ivoire   PMO - US     From RDC   N/A - From RDC         Truck
# 10321         Zambia   PMO - US     From RDC   N/A - From RDC         Truck
# 10322       Zimbabwe   PMO - US     From RDC   N/A - From RDC         Truck
# 10323       Zimbabwe   PMO - US     From RDC   N/A - From RDC         Truck
#
# ...

# %%
data.columns
# Out:
# Index(['Country', 'Managed_By', 'Fulfill_Via', 'Vendor_INCO_Term',
#        'Shipment_Mode', 'Scheduled_Delivery_Date', 'Delivered_to_Client_Date',
#        'Delivery_Recorded_Date', 'Product_Group', 'Sub_Classification',
#        'Vendor', 'Item_Description', 'Molecule/Test_Type', 'Brand', 'Dosage',
#        'Dosage_Form', 'Unit_of_Measure_(Per_Pack)', 'Line_Item_Quantity',
#        'Line_Item_Value', 'Pack_Price', 'Unit_Price', 'Manufacturing_Site',
#        'First_Line_Designation', 'Weight_(Kilograms)', 'Freight_Cost_(USD)',
#        'Line_Item_Insurance_(USD)'],
#       dtype='object')

# %%
data.drop(['Freight_Cost_(USD)'], axis=1 , inplace=True)

# %%
data
# Out:
#              Country Managed_By  Fulfill_Via Vendor_INCO_Term Shipment_Mode  \
# 0      Côte d'Ivoire   PMO - US  Direct Drop              EXW           Air
# 1            Vietnam   PMO - US  Direct Drop              EXW           Air
# 2      Côte d'Ivoire   PMO - US  Direct Drop              FCA           Air
# 3            Vietnam   PMO - US  Direct Drop              EXW           Air
# 4            Vietnam   PMO - US  Direct Drop              EXW           Air
# ...              ...        ...          ...              ...           ...
# 10319       Zimbabwe   PMO - US     From RDC   N/A - From RDC         Truck
# 10320  Côte d'Ivoire   PMO - US     From RDC   N/A - From RDC         Truck
# 10321         Zambia   PMO - US     From RDC   N/A - From RDC         Truck
# 10322       Zimbabwe   PMO - US     From RDC   N/A - From RDC         Truck
# 10323       Zimbabwe   PMO - US     From RDC   N/A - From RDC         Truck
#
# ...

# %%
# convert datatype 


data['Weight_(Kilograms)']  =  data['Weight_(Kilograms)'].apply(pd.to_numeric , errors="coerce")

# %%
data['Weight_(Kilograms)'].isnull().mean()
# Out:
# 0.38279736536226266

# %%
data.drop(['Weight_(Kilograms)'], axis=1 , inplace=True)

# %%
data
# Out:
#              Country Managed_By  Fulfill_Via Vendor_INCO_Term Shipment_Mode  \
# 0      Côte d'Ivoire   PMO - US  Direct Drop              EXW           Air
# 1            Vietnam   PMO - US  Direct Drop              EXW           Air
# 2      Côte d'Ivoire   PMO - US  Direct Drop              FCA           Air
# 3            Vietnam   PMO - US  Direct Drop              EXW           Air
# 4            Vietnam   PMO - US  Direct Drop              EXW           Air
# ...              ...        ...          ...              ...           ...
# 10319       Zimbabwe   PMO - US     From RDC   N/A - From RDC         Truck
# 10320  Côte d'Ivoire   PMO - US     From RDC   N/A - From RDC         Truck
# 10321         Zambia   PMO - US     From RDC   N/A - From RDC         Truck
# 10322       Zimbabwe   PMO - US     From RDC   N/A - From RDC         Truck
# 10323       Zimbabwe   PMO - US     From RDC   N/A - From RDC         Truck
#
# ...

# %%
# object types data
object_columns = [x for x in data.select_dtypes(include=["object"])]

# %%
object_columns_less_than_1200 = [print (f"{columns} :  {len(data[columns].unique())}") for columns in object_columns if len(data[columns].unique()) < 1200]
# Out:
# Country :  43
# Managed_By :  4
# Fulfill_Via :  2
# Vendor_INCO_Term :  8
# Shipment_Mode :  5
# Product_Group :  5
# Sub_Classification :  6
# Vendor :  73
# Item_Description :  184
# Molecule/Test_Type :  86
# Brand :  48
# Dosage :  55
# Dosage_Form :  17
# Manufacturing_Site :  88
# First_Line_Designation :  2

# %%
object_columns_less_than_1200
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
data.columns
# Out:
# Index(['Country', 'Managed_By', 'Fulfill_Via', 'Vendor_INCO_Term',
#        'Shipment_Mode', 'Scheduled_Delivery_Date', 'Delivered_to_Client_Date',
#        'Delivery_Recorded_Date', 'Product_Group', 'Sub_Classification',
#        'Vendor', 'Item_Description', 'Molecule/Test_Type', 'Brand', 'Dosage',
#        'Dosage_Form', 'Unit_of_Measure_(Per_Pack)', 'Line_Item_Quantity',
#        'Line_Item_Value', 'Pack_Price', 'Unit_Price', 'Manufacturing_Site',
#        'First_Line_Designation', 'Line_Item_Insurance_(USD)'],
#       dtype='object')

# %%
data["Delivered_to_Client_Date"] = data["Delivered_to_Client_Date"].astype("datetime64")

# %%
#data["Delivered_to_Client_Date"] = pd.to_datetime(data["Delivered_to_Client_Date"] , format="%Y-%m-%d")

# %%
data["Scheduled_Delivery_Date"] = data["Scheduled_Delivery_Date"].astype("datetime64")

# %%
#data['Scheduled_Delivery_Date'] = pd.to_datetime(data["Scheduled_Delivery_Date"] , format="%Y-%m-%d")

# %%
data["Delivered_to_Client_Date"]
# Out:
# 0       2006-06-02
# 1       2006-11-14
# 2       2006-08-27
# 3       2006-09-01
# 4       2006-08-11
#            ...
# 10319   2015-07-15
# 10320   2015-08-06
# 10321   2015-08-25
# 10322   2015-08-04
# 10323   2015-08-04
# Name: Delivered_to_Client_Date, Length: 10324, dtype: datetime64[ns]

# %%
data['Scheduled_Delivery_Date']
# Out:
# 0       2006-06-02
# 1       2006-11-14
# 2       2006-08-27
# 3       2006-09-01
# 4       2006-08-11
#            ...
# 10319   2015-07-31
# 10320   2015-07-31
# 10321   2015-08-31
# 10322   2015-09-09
# 10323   2015-08-31
# Name: Scheduled_Delivery_Date, Length: 10324, dtype: datetime64[ns]

# %%
 data['Delivery_Recorded_Date']
# Out:
# 0         2-Jun-06
# 1        14-Nov-06
# 2        27-Aug-06
# 3         1-Sep-06
# 4        11-Aug-06
#            ...
# 10319    20-Jul-15
# 10320     7-Aug-15
# 10321     3-Sep-15
# 10322    11-Aug-15
# 10323    11-Aug-15
# Name: Delivery_Recorded_Date, Length: 10324, dtype: object

# %%
data["Delivered_to_Client_Date"].astype("datetime64")
# Out:
# 0       2006-06-02
# 1       2006-11-14
# 2       2006-08-27
# 3       2006-09-01
# 4       2006-08-11
#            ...
# 10319   2015-07-15
# 10320   2015-08-06
# 10321   2015-08-25
# 10322   2015-08-04
# 10323   2015-08-04
# Name: Delivered_to_Client_Date, Length: 10324, dtype: datetime64[ns]

# %%
data['Time_to_reach_at_destination'] = data['Scheduled_Delivery_Date'] - data["Delivered_to_Client_Date"]

# %%
data['Time_to_reach_at_destination'] = data['Time_to_reach_at_destination'].dt.days

# %%
data
# Out:
#              Country Managed_By  Fulfill_Via Vendor_INCO_Term Shipment_Mode  \
# 0      Côte d'Ivoire   PMO - US  Direct Drop              EXW           Air
# 1            Vietnam   PMO - US  Direct Drop              EXW           Air
# 2      Côte d'Ivoire   PMO - US  Direct Drop              FCA           Air
# 3            Vietnam   PMO - US  Direct Drop              EXW           Air
# 4            Vietnam   PMO - US  Direct Drop              EXW           Air
# ...              ...        ...          ...              ...           ...
# 10319       Zimbabwe   PMO - US     From RDC   N/A - From RDC         Truck
# 10320  Côte d'Ivoire   PMO - US     From RDC   N/A - From RDC         Truck
# 10321         Zambia   PMO - US     From RDC   N/A - From RDC         Truck
# 10322       Zimbabwe   PMO - US     From RDC   N/A - From RDC         Truck
# 10323       Zimbabwe   PMO - US     From RDC   N/A - From RDC         Truck
#
# ...

# %%
data.columns
# Out:
# Index(['Country', 'Managed_By', 'Fulfill_Via', 'Vendor_INCO_Term',
#        'Shipment_Mode', 'Scheduled_Delivery_Date', 'Delivered_to_Client_Date',
#        'Delivery_Recorded_Date', 'Product_Group', 'Sub_Classification',
#        'Vendor', 'Item_Description', 'Molecule/Test_Type', 'Brand', 'Dosage',
#        'Dosage_Form', 'Unit_of_Measure_(Per_Pack)', 'Line_Item_Quantity',
#        'Line_Item_Value', 'Pack_Price', 'Unit_Price', 'Manufacturing_Site',
#        'First_Line_Designation', 'Line_Item_Insurance_(USD)',
#        'Time_to_reach_at_destination'],
#       dtype='object')

# %%
data.drop(["Scheduled_Delivery_Date" , "Delivered_to_Client_Date" ], axis=1 , inplace=True)

# %%
data
# Out:
#              Country Managed_By  Fulfill_Via Vendor_INCO_Term Shipment_Mode  \
# 0      Côte d'Ivoire   PMO - US  Direct Drop              EXW           Air
# 1            Vietnam   PMO - US  Direct Drop              EXW           Air
# 2      Côte d'Ivoire   PMO - US  Direct Drop              FCA           Air
# 3            Vietnam   PMO - US  Direct Drop              EXW           Air
# 4            Vietnam   PMO - US  Direct Drop              EXW           Air
# ...              ...        ...          ...              ...           ...
# 10319       Zimbabwe   PMO - US     From RDC   N/A - From RDC         Truck
# 10320  Côte d'Ivoire   PMO - US     From RDC   N/A - From RDC         Truck
# 10321         Zambia   PMO - US     From RDC   N/A - From RDC         Truck
# 10322       Zimbabwe   PMO - US     From RDC   N/A - From RDC         Truck
# 10323       Zimbabwe   PMO - US     From RDC   N/A - From RDC         Truck
#
# ...

# %%
data['Delivery_Recorded_Date'] = data['Delivery_Recorded_Date'].astype('datetime64[ns]')
data['Delivery_Recorded_Date_year'] = data['Delivery_Recorded_Date'].dt.year
data['Delivery_Recorded_Date_days'] = data['Delivery_Recorded_Date'].dt.day
data['Delivery_Recorded_Date_month'] = data['Delivery_Recorded_Date'].dt.month
data.drop(['Delivery_Recorded_Date'], axis=1 , inplace=True)

# %%
data
# Out:
#              Country Managed_By  Fulfill_Via Vendor_INCO_Term Shipment_Mode  \
# 0      Côte d'Ivoire   PMO - US  Direct Drop              EXW           Air
# 1            Vietnam   PMO - US  Direct Drop              EXW           Air
# 2      Côte d'Ivoire   PMO - US  Direct Drop              FCA           Air
# 3            Vietnam   PMO - US  Direct Drop              EXW           Air
# 4            Vietnam   PMO - US  Direct Drop              EXW           Air
# ...              ...        ...          ...              ...           ...
# 10319       Zimbabwe   PMO - US     From RDC   N/A - From RDC         Truck
# 10320  Côte d'Ivoire   PMO - US     From RDC   N/A - From RDC         Truck
# 10321         Zambia   PMO - US     From RDC   N/A - From RDC         Truck
# 10322       Zimbabwe   PMO - US     From RDC   N/A - From RDC         Truck
# 10323       Zimbabwe   PMO - US     From RDC   N/A - From RDC         Truck
#
#       Product_Group Sub_Classification  \
# ...

# %%
data.columns
# Out:
# Index(['Country', 'Managed_By', 'Fulfill_Via', 'Vendor_INCO_Term',
#        'Shipment_Mode', 'Product_Group', 'Sub_Classification', 'Vendor',
#        'Item_Description', 'Molecule/Test_Type', 'Brand', 'Dosage',
#        'Dosage_Form', 'Unit_of_Measure_(Per_Pack)', 'Line_Item_Quantity',
#        'Line_Item_Value', 'Pack_Price', 'Unit_Price', 'Manufacturing_Site',
#        'First_Line_Designation', 'Line_Item_Insurance_(USD)',
#        'Time_to_reach_at_destination', 'Delivery_Recorded_Date_year',
#        'Delivery_Recorded_Date_days', 'Delivery_Recorded_Date_month'],
#       dtype='object')

# %%
data
# Out:
#              Country Managed_By  Fulfill_Via Vendor_INCO_Term Shipment_Mode  \
# 0      Côte d'Ivoire   PMO - US  Direct Drop              EXW           Air
# 1            Vietnam   PMO - US  Direct Drop              EXW           Air
# 2      Côte d'Ivoire   PMO - US  Direct Drop              FCA           Air
# 3            Vietnam   PMO - US  Direct Drop              EXW           Air
# 4            Vietnam   PMO - US  Direct Drop              EXW           Air
# ...              ...        ...          ...              ...           ...
# 10319       Zimbabwe   PMO - US     From RDC   N/A - From RDC         Truck
# 10320  Côte d'Ivoire   PMO - US     From RDC   N/A - From RDC         Truck
# 10321         Zambia   PMO - US     From RDC   N/A - From RDC         Truck
# 10322       Zimbabwe   PMO - US     From RDC   N/A - From RDC         Truck
# 10323       Zimbabwe   PMO - US     From RDC   N/A - From RDC         Truck
#
#       Product_Group Sub_Classification  \
# ...

# %%
# object types data
object_columns = [x for x in data.select_dtypes(include=["object"])]

# %%
len(object_columns)
# Out:
# 15

# %%
[x for x in data.select_dtypes(include=["int" , "float"])]
# Out:
# ['Unit_of_Measure_(Per_Pack)',
#  'Line_Item_Quantity',
#  'Line_Item_Value',
#  'Pack_Price',
#  'Unit_Price',
#  'Line_Item_Insurance_(USD)',
#  'Time_to_reach_at_destination',
#  'Delivery_Recorded_Date_year',
#  'Delivery_Recorded_Date_days',
#  'Delivery_Recorded_Date_month']

# %%
data.isnull().sum()
# Out:
# Country                            0
# Managed_By                         0
# Fulfill_Via                        0
# Vendor_INCO_Term                   0
# Shipment_Mode                    360
# Product_Group                      0
# Sub_Classification                 0
# Vendor                             0
# Item_Description                   0
# Molecule/Test_Type                 0
# Brand                              0
# Dosage                          1736
# Dosage_Form                        0
# Unit_of_Measure_(Per_Pack)         0
# Line_Item_Quantity                 0
# Line_Item_Value                    0
# Pack_Price                         0
# Unit_Price                         0
# Manufacturing_Site                 0
# First_Line_Designation             0
# Line_Item_Insurance_(USD)        287
# Time_to_reach_at_destination       0
# Delivery_Recorded_Date_year        0
# Delivery_Recorded_Date_days        0
# Delivery_Recorded_Date_month       0
# dtype: int64

# %%
data.drop(['Dosage', "Dosage_Form"], axis=1 , inplace=True)

# %% [markdown]
# ## Impute missing values

# %%
data["Shipment_Mode"].fillna(data["Shipment_Mode"].mode()[0] , inplace=True)
data["Line_Item_Insurance_(USD)"].fillna(data["Line_Item_Insurance_(USD)"].median() , inplace=True)

# %%
data.isnull().sum()
# Out:
# Country                         0
# Managed_By                      0
# Fulfill_Via                     0
# Vendor_INCO_Term                0
# Shipment_Mode                   0
# Product_Group                   0
# Sub_Classification              0
# Vendor                          0
# Item_Description                0
# Molecule/Test_Type              0
# Brand                           0
# Unit_of_Measure_(Per_Pack)      0
# Line_Item_Quantity              0
# Line_Item_Value                 0
# Pack_Price                      0
# Unit_Price                      0
# Manufacturing_Site              0
# First_Line_Designation          0
# Line_Item_Insurance_(USD)       0
# Time_to_reach_at_destination    0
# Delivery_Recorded_Date_year     0
# Delivery_Recorded_Date_days     0
# Delivery_Recorded_Date_month    0
# dtype: int64

# %% [markdown]
# ## One Hot Encoding

# %%
object_columns
# Out:
# ['Country',
#  'Managed_By',
#  'Fulfill_Via',
#  'Vendor_INCO_Term',
#  'Shipment_Mode',
#  'Product_Group',
#  'Sub_Classification',
#  'Vendor',
#  'Item_Description',
#  'Molecule/Test_Type',
#  'Brand',
#  'Manufacturing_Site',
#  'First_Line_Designation']

# %%
Data = pd.get_dummies(data , columns=object_columns , drop_first=True)

# %%
Data
# Out:
#        Unit_of_Measure_(Per_Pack)  Line_Item_Quantity  Line_Item_Value  \
# 0                              30                  19           551.00
# 1                             240                1000          6200.00
# 2                             100                 500         40000.00
# 3                              60               31920        127360.80
# 4                              60               38000        121600.00
# ...                           ...                 ...              ...
# 10319                          60              166571        599655.60
# 10320                          60               21072        137389.44
# 10321                          30              514526       5140114.74
# 10322                          60               17465        113871.80
# 10323                          60               36639         72911.61
#
#        Pack_Price  Unit_Price  Line_Item_Insurance_(USD)  \
# ...

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10324 entries, 0 to 10323
# Columns: 550 entries, Unit_of_Measure_(Per_Pack) to First_Line_Designation_Yes
# dtypes: float64(4), int64(6), uint8(540)
# memory usage: 6.1 MB

# %% [markdown]
# # Visualize

# %%
## Sc
